# %%
# The code was removed by Watson Studio for sharing.
# Out:
#   event_id_cnty event_date year time_precision disorder_type
# 1 BRA93318      2025-01-10 2025 1              Political violence
# 2 GHA2554       2025-01-10 2025 2              Demonstrations
# 3 LBY11884      2025-01-10 2025 2              Political violence
# 4 TUR39344      2025-01-10 2025 1              Demonstrations
# 5 TUR39392      2025-01-10 2025 1              Demonstrations
# 6 YEM94805      2025-01-10 2025 1              Demonstrations
#   event_type                 sub_event_type
# 1 Violence against civilians Attack
# 2 Protests                   Peaceful protest
# 3 Violence against civilians Attack
# 4 Protests                   Peaceful protest
# 5 Protests                   Peaceful protest
# 6 Protests                   Peaceful protest
#   actor1
# 1 Military Forces of Brazil (2023-) Military Police
# 2 Protesters (Ghana)
# 3 Unidentified Armed Group (Libya)
# 4 Protesters (Turkey)
# 5 Protesters (Turkey)
# 6 Protesters (Yemen)
#   assoc_actor_1
# 1
# ...

# %%
str(df_1)
# Out:
# 'data.frame':	79282 obs. of  31 variables:
#  $ event_id_cnty     : chr  "BRA93318" "GHA2554" "LBY11884" "TUR39344" ...
#  $ event_date        : chr  "2025-01-10" "2025-01-10" "2025-01-10" "2025-01-10" ...
#  $ year              : int  2025 2025 2025 2025 2025 2025 2025 2025 2025 2025 ...
#  $ time_precision    : int  1 2 2 1 1 1 1 1 1 1 ...
#  $ disorder_type     : chr  "Political violence" "Demonstrations" "Political violence" "Demonstrations" ...
#  $ event_type        : chr  "Violence against civilians" "Protests" "Violence against civilians" "Protests" ...
#  $ sub_event_type    : chr  "Attack" "Peaceful protest" "Attack" "Peaceful protest" ...
#  $ actor1            : chr  "Military Forces of Brazil (2023-) Military Police" "Protesters (Ghana)" "Unidentified Armed Group (Libya)" "Protesters (Turkey)" ...
# ...

# %%
summary(df_1)
# Out:
#  event_id_cnty       event_date             year      time_precision
#  Length:79282       Length:79282       Min.   :1997   Min.   :1.000
#  Class :character   Class :character   1st Qu.:2020   1st Qu.:1.000
#  Mode  :character   Mode  :character   Median :2021   Median :1.000
#                                        Mean   :2021   Mean   :1.096
#                                        3rd Qu.:2023   3rd Qu.:1.000
#                                        Max.   :2025   Max.   :3.000
#  disorder_type       event_type        sub_event_type        actor1
#  Length:79282       Length:79282       Length:79282       Length:79282
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#  assoc_actor_1         inter1             actor2          assoc_actor_2
#  Length:79282       Length:79282       Length:79282       Length:79282
# ...

# %%
sum(is.na(df_1))
